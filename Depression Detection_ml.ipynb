# %%
import numpy as np
import pandas as pd
final = pd.read_csv(r"C:/Users/user/Downloads/finall.csv")
final
# Out:
#       Is there anyone in your life who can support you and be there for you?  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1045                                                  0
# 1046                                                  0
# 1047                                                  1
# 1048                                                  0
# 1049                                                  1
#
#       How were you feeling lately?  Have you been sleeping well?  \
# 0                                3                             0
# 1                                1                             1
# 2                                4                             0
# ...

# %%
negative_list = []
positive_list = []
for i in range(1050):
    pos = 0
    neg = 0
    row = final.iloc[i].values

    if row[0]==1 :
        pos+=1
    else:
        neg+=1

    if row[1]<=3 :
        pos+=1
    else:
        neg+=1   

    if row[2]==1 :
        pos+=1
    else:
        neg+=1
    if row[3]==1 :
        pos+=1
    else:
        neg+=1

    if row[4]==1 :
        pos+=1
    else:
        neg+=1
    if row[5]==1 :
        pos+=1
    else:
        neg+=1

    if row[6]==0 :
        pos+=1
    else:
        neg+=1
    if row[7]>0:
        pos+=1
    else:
        neg+=1

    if row[8]>0:
        pos+=1
    else:
        neg+=1
    if row[9]>0:
        pos+=1
    else:
        neg+=1
    negative_list.append(neg)
    positive_list.append(pos)

# %%
final["positive"] = positive_list
final["negative"] = negative_list

final
# Out:
#       Is there anyone in your life who can support you and be there for you?  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1045                                                  0
# 1046                                                  0
# 1047                                                  1
# 1048                                                  0
# 1049                                                  1
#
#       How were you feeling lately?  Have you been sleeping well?  \
# 0                                3                             0
# 1                                1                             1
# 2                                4                             0
# ...

# %%
result = []
for i in positive_list:
    if i>=6 and i<=10:
        result.append("No Depression")
    elif i==4 or i==5:
        result.append("Minor Depression")
    else:
        result.append("Major Depression")
final["result"] = result
final
# Out:
#       Is there anyone in your life who can support you and be there for you?  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1045                                                  0
# 1046                                                  0
# 1047                                                  1
# 1048                                                  0
# 1049                                                  1
#
#       How were you feeling lately?  Have you been sleeping well?  \
# 0                                3                             0
# 1                                1                             1
# 2                                4                             0
# ...

# %%
X = final.drop(["result","positive", "negative"], axis=1)
y = final["result"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X,y)
y_test
# Out:
# 96         No Depression
# 584        No Depression
# 395        No Depression
# 362        No Depression
# 1013    Minor Depression
#               ...
# 962        No Depression
# 1018       No Depression
# 446        No Depression
# 603        No Depression
# 735        No Depression
# Name: result, Length: 263, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_preds = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_preds)
# Out:
# 0.8935361216730038

# %%
import pickle
pickle.dump(model, open('model.pkl', 'wb'))

# %%
final.to_csv("Depression_dataset.csv", index=False)

# %%
df  = pd.read_excel(r"C:/Users/user/Downloads/depression dataset modified.csv.xlsx")
df
# Out:
#     Is there anyone in your life who can support you and be there for you?  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   0
# 4                                                   0
# 5                                                   1
# 6                                                   1
# 7                                                   0
# 8                                                   1
# 9                                                   1
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  1
# 14                                                  1
# 15                                                  1
# ...

# %%
X = df.drop(["Result", "positive", "negative"], axis=1)

y = df["Result"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7392\2368563623.py in <module>
# ----> 1 X = df.drop(["Result", "positive", "negative"], axis=1)
#       2
#       3 y = df["Result"]
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X,y)
y_test
# Out:
# 48       No Depression
# 37    Minor Depression
# 17       No Depression
# 29    Major Depression
# 46       No Depression
# 2     Minor Depression
# 7     Major Depression
# 47    Major Depression
# 21    Minor Depression
# 15       No Depression
# 45    Major Depression
# 10    Minor Depression
# 31    Minor Depression
# Name: Result, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_preds = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_preds)
# Out:
# 1.0

# %%
y_test
# Out:
# 48       No Depression
# 37    Minor Depression
# 17       No Depression
# 29    Major Depression
# 46       No Depression
# 2     Minor Depression
# 7     Major Depression
# 47    Major Depression
# 21    Minor Depression
# 15       No Depression
# 45    Major Depression
# 10    Minor Depression
# 31    Minor Depression
# Name: Result, dtype: object

# %%
y_preds
# Out:
# array(['No Depression', 'Minor Depression', 'No Depression',
#        'Major Depression', 'No Depression', 'Minor Depression',
#        'Major Depression', 'Major Depression', 'Minor Depression',
#        'No Depression', 'Major Depression', 'Minor Depression',
#        'Minor Depression'], dtype=object)
